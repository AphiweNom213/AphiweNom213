# %% [markdown]
# <a href="https://colab.research.google.com/github/AphiweNom213/AphiweNom213/blob/main/Comparisons%20in%20temp%20and%20coffee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
db = pd.read_excel("/content/sample_data/cafedata (1).xlsx")
db
# Out:
#      t       Date  Day Code Day of Week  Bread Sand Sold  Bread Sand Waste  \
# 0    1 2010-01-19         2         Tue                5                 3
# 1    2 2010-01-20         3         Wed                6                 8
# 2    3 2010-01-21         4         Thu                8                 2
# 3    4 2010-01-22         5         Fri                4                 2
# 4    5 2010-01-25         1         Mon                3                 0
# 5    6 2010-01-26         2         Tue                7                 1
# 6    7 2010-01-27         3         Wed                6                 6
# 7    8 2010-01-28         4         Thu                0                 0
# 8    9 2010-01-29         5         Fri                3                 4
# 9   10 2010-02-01         1         Mon                2                 6
# 10  11 2010-02-02         2         Tue                3                 7
# ...

# %%
from matplotlib import pyplot as plt
db.plot(kind='scatter', x='Max Daily Temperature (F)', y='Coffees', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
